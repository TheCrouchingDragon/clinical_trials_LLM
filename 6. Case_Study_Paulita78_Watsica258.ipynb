#  Sibyl335_Bernier607_6f1c5c00-112e-4bcd-ae37-388e6552e10e.json
#  Sirena316_McClure239_fd79b91b-5016-4053-82d8-5cb52a533380.json
#  Sofia418_Mata817_e026fc6f-e39a-4c89-91bb-e8b81bb46c7c.json
#  Sondra191_Gislason620_c0b387e4-9a58-4a03-9e98-cdd99f839d4f.json
#  Suk497_Hermann103_d8a5ea0e-e2af-4ac2-b9b7-a8ff4c828ab0.json
#  Tabetha269_Legros616_2d49dda8-fef8-492d-aa8e-0e9d382c1f1d.json
#  Tambra47_Lang846_ae6b9280-f98d-455b-87fa-cc576ab01d2d.json
#  Tamekia382_Larson43_80cc0c70-806c-4f8b-9b19-09fc0d40ea43.json
#  Taren286_Zulauf375_ba58d4a4-72fd-41e1-afda-cead75410658.json
#  Terrilyn343_Barrows492_8f66ad1f-9767-41ed-8de8-a9a8da99ad3c.json
#  Tiny880_Legros616_a0c65a8f-ef0a-44bc-919b-7288d1e443f1.json
#  Tonisha838_Steuber698_a105f929-1af0-41e8-80b2-28239c56c519.json
#  Tory770_DuBuque211_42627ef0-ea02-4323-8059-c8dfb6125314.json
#  Tula326_Ward668_e74a3332-2b54-4806-b8fb-d750005cefdd.json
#  Verlene883_Lang846_e10ec25a-1a5c-4b60-9a2d-110f276c25ee.json
#  Veronique514_Koepp521_874cbeae-3145-40a1-940a-b5fed8a60f99.json
#  Vivian245_Dach178_37fd5091-034d-40d1-9d85-252c8b399c13.json
#  Wava789_Corwin846_1e208b6b-77f1-4808-a32b-9f9caf1ec334.json
#  Xenia801_Adams676_ccef190b-3282-47a3-8a38-be111c4ab299.json
#  Yael855_Stroman228_6fa5f169-73e1-4921-bf34-4bd08f350e88.json
#  Yasmin241_Maggio310_1a1a8552-2654-46c0-9f26-f92f7010e923.json
#  Yetta429_Dibbert990_ffd2246e-31c3-4cd3-99ed-62328029fa0d.json
#  Ying817_Cole117_2317abf3-9bee-481e-82c3-524456d1ec2b.json

# %%
import json
from collections import defaultdict
import pandas as pd

# Load the JSON file to extract information
with open("/content/drive/MyDrive/synthea_dataset/Paulita78_Watsica258_2dcefbbe-9f7c-4253-85f8-e1f0e74d90c1.json") as f:
    data = json.load(f)

patient={}

# Extract the entries
entries = data.get('entry', [])

# Group by resourceType
resource_dict = {}
for entry in entries:
    resource = entry.get('resource', {})
    resource_type = resource.get('resourceType', 'Unknown')
    if resource_type not in resource_dict:
        resource_dict[resource_type] = []
    resource_dict[resource_type].append(resource)

# %%
def flatten_dataframe(df):
    for column in df.columns:
        if df[column].apply(lambda x: isinstance(x, (list, dict))).any():
            # Normalize the nested column
            normalized_df = pd.json_normalize(df[column].explode().dropna().tolist(), sep='_')
            normalized_df.columns = [f"{column}_{sub_col}" for sub_col in normalized_df.columns]
            # Drop the original nested column and join the normalized columns
            df = df.drop(columns=[column]).join(normalized_df)
    return df

# %%
print(resource_dict.keys())
# Out:
# dict_keys(['Patient', 'Location', 'Organization', 'Practitioner', 'PractitionerRole', 'Encounter', 'Observation', 'Procedure', 'DiagnosticReport', 'DocumentReference', 'Immunization', 'Condition', 'MedicationRequest', 'CareTeam', 'CarePlan'])

# %%
for resource_type, resources in resource_dict.items():
    print(f"ResourceType: {resource_type}")
    # Normalize the entire resource dictionary and separate nested tags
    df = pd.json_normalize(resources, sep='_')
    #print(df.columns)

    # Flatten the nested columns
    df = flatten_dataframe(df)

    # Filter out inactive patient information
    if 'status' in df.columns:
      print(df['status'].unique())
        #df = df[(df['status'] == 'active') | (df['status'] == 'current') | (df['status'] == 'final') | (df['status'] == 'finished') | (df['status'] == 'completed')]

    if 'id' in df.columns:
        df = df.drop(columns=['id'])

    columns_to_drop = [col for col in df.columns if any(substring in col for substring in ['reference', 'system', 'telecom', 'identifier', 'Identifier', 'uid', 'Address', 'address'])]
    df = df.drop(columns=columns_to_drop)

    df = flatten_dataframe(df) #handle second layer of nesting

    print(df.columns)
    #print(df.head(2))

    patient[resource_type] = df
    print('\n')
# Out:
# ResourceType: Patient
# Index(['resourceType', 'gender', 'birthDate', 'multipleBirthBoolean',
#        'text_status', 'text_div', 'maritalStatus_text', 'extension_url',
#        'extension_valueString', 'extension_valueCode',
#        'extension_valueDecimal', 'name_use', 'name_family',
#        'communication_language_text', 'maritalStatus_coding_code',
#        'maritalStatus_coding_display', 'extension_extension_url',
#        'extension_extension_valueCoding_system',
#        'extension_extension_valueCoding_code',
#        'extension_extension_valueCoding_display',
#        'extension_extension_valueString',
#        'communication_language_coding_system',
#        'communication_language_coding_code',
#        'communication_language_coding_display'],
#       dtype='object')
#
#
# ResourceType: Location
# ['active']
# Index(['resourceType', 'status', 'name', 'position_longitude',
#        'position_latitude', 'managingOrganization_display'],
#       dtype='object')
#
#
# ResourceType: Organization
# Index(['resourceType', 'active', 'name', 'type_text', 'type_coding_system',
#        'type_coding_code', 'type_coding_display'],
#       dtype='object')
#
#
# ResourceType: Practitioner
# Index(['resourceType', 'active', 'gender', 'name_family'], dtype='object')
#
#
# ResourceType: PractitionerRole
# Index(['resourceType', 'practitioner_display', 'organization_display',
#        'code_text', 'specialty_text', 'location_display', 'code_coding_system',
#        'code_coding_code', 'code_coding_display', 'specialty_coding_system',
#        'specialty_coding_code', 'specialty_coding_display'],
#       dtype='object')
#
#
# ResourceType: Encounter
# ['finished']
# Index(['resourceType', 'status', 'class_code', 'subject_display',
#        'period_start', 'period_end', 'serviceProvider_display', 'type_text',
#        'participant_period_start', 'participant_period_end',
#        'participant_individual_display', 'location_location_display',
#        'type_coding_system', 'type_coding_code', 'type_coding_display',
#        'participant_type_coding', 'participant_type_text',
#        'reasonCode_coding_system', 'reasonCode_coding_code',
#        'reasonCode_coding_display'],
#       dtype='object')
#
#
# ResourceType: Observation
# ['final']
# Index(['resourceType', 'status', 'effectiveDateTime', 'issued', 'code_text',
#        'valueQuantity_value', 'valueQuantity_unit', 'valueQuantity_code',
#        'valueCodeableConcept_text', 'code_coding_code', 'code_coding_display',
#        'component_code_text', 'component_valueQuantity_value',
#        'component_valueQuantity_unit', 'component_valueQuantity_code',
#        'valueCodeableConcept_coding_code',
#        'valueCodeableConcept_coding_display', 'category_coding_system',
#        'category_coding_code', 'category_coding_display',
#        'component_code_coding_system', 'component_code_coding_code',
#        'component_code_coding_display'],
#       dtype='object')
#
#
# ResourceType: Procedure
# ['completed']
# Index(['resourceType', 'status', 'code_text', 'performedPeriod_start',
#        'performedPeriod_end', 'location_display', 'code_coding_code',
#        'code_coding_display', 'reasonReference_display'],
#       dtype='object')
#
#
# ResourceType: DiagnosticReport
# ['final']
# Index(['resourceType', 'status', 'effectiveDateTime', 'issued', 'code_text',
#        'performer_display', 'result_display', 'code_coding_code',
#        'code_coding_display', 'presentedForm_contentType',
#        'presentedForm_data', 'category_coding_system', 'category_coding_code',
#        'category_coding_display'],
#       dtype='object')
#
#
# ResourceType: DocumentReference
# ['superseded' 'current']
# Index(['resourceType', 'status', 'date', 'custodian_display',
#        'context_period_start', 'context_period_end', 'author_display',
#        'content_attachment_contentType', 'content_attachment_data',
#        'content_format_code', 'content_format_display', 'type_coding_code',
#        'type_coding_display', 'category_coding_system', 'category_coding_code',
#        'category_coding_display'],
#       dtype='object')
#
#
# ResourceType: Immunization
# ['completed']
# Index(['resourceType', 'status', 'occurrenceDateTime', 'primarySource',
#        'vaccineCode_text', 'location_display', 'vaccineCode_coding_code',
#        'vaccineCode_coding_display'],
#       dtype='object')
#
#
# ResourceType: Condition
# Index(['resourceType', 'onsetDateTime', 'abatementDateTime', 'recordedDate',
#        'code_text', 'clinicalStatus_coding_code',
#        'verificationStatus_coding_code', 'code_coding_code',
#        'code_coding_display', 'stage_summary_text', 'category_coding_system',
#        'category_coding_code', 'category_coding_display',
#        'stage_assessment_reference', 'stage_type_coding_system',
#        'stage_type_coding_code', 'stage_type_coding_display',
#        'stage_summary_coding_system', 'stage_summary_coding_code',
#        'stage_summary_coding_display'],
#       dtype='object')
#
#
# ResourceType: MedicationRequest
# ['completed']
# Index(['resourceType', 'status', 'intent', 'authoredOn',
#        'medicationCodeableConcept_text', 'requester_display',
#        'medicationCodeableConcept_coding_code',
#        'medicationCodeableConcept_coding_display'],
#       dtype='object')
#
#
# ResourceType: CareTeam
# ['inactive']
# Index(['resourceType', 'status', 'period_start', 'period_end',
#        'participant_member_display', 'reasonCode_text',
#        'managingOrganization_display', 'participant_role_coding',
#        'participant_role_text', 'reasonCode_coding_system',
#        'reasonCode_coding_code', 'reasonCode_coding_display'],
#       dtype='object')
#
#
# ResourceType: CarePlan
# ['completed']
# Index(['resourceType', 'status', 'intent', 'text_status', 'text_div',
#        'period_start', 'period_end', 'category_text',
#        'activity_detail_code_text', 'activity_detail_status',
#        'activity_detail_location_display', 'category_coding_system',
#        'category_coding_code', 'category_coding_display',
#        'activity_detail_code_coding_system',
#        'activity_detail_code_coding_code',
#        'activity_detail_code_coding_display'],
#       dtype='object')

# %%
for resource_type, resources in resource_dict.items():
  print(patient[resource_type].head(2))
# Out:
#   resourceType  gender   birthDate  multipleBirthBoolean text_status  \
# 0      Patient  female  1968-03-10                 False   generated
#
#                                             text_div maritalStatus_text  \
# 0  <div xmlns="http://www.w3.org/1999/xhtml">Gene...                  M
#
#                                        extension_url extension_valueString  \
# 0  http://hl7.org/fhir/us/core/StructureDefinitio...                   NaN
#
#   extension_valueCode  ...  maritalStatus_coding_code  \
# 0                 NaN  ...                          M
#
#   maritalStatus_coding_display extension_extension_url  \
# 0                            M             ombCategory
#
#   extension_extension_valueCoding_system extension_extension_valueCoding_code  \
# 0        urn:oid:2.16.840.1.113883.6.238                               2106-3
#
#   extension_extension_valueCoding_display extension_extension_valueString  \
# 0                                   White                             NaN
#
#   communication_language_coding_system communication_language_coding_code  \
# 0                      urn:ietf:bcp:47                              en-US
#
#   communication_language_coding_display
# 0                               English
#
# [1 rows x 24 columns]
#   resourceType  status                         name  position_longitude  \
# 0     Location  active  MOUNT HOPE PHYSICAL THERAPY          -71.214181
# 1     Location  active        SAINT ANNE'S HOSPITAL          -71.094162
#
#    position_latitude managingOrganization_display
# 0          41.758163  MOUNT HOPE PHYSICAL THERAPY
# 1          41.725351        SAINT ANNE'S HOSPITAL
#    resourceType  active                         name            type_text  \
# 0  Organization    True  MOUNT HOPE PHYSICAL THERAPY  Healthcare Provider
# 1  Organization    True        SAINT ANNE'S HOSPITAL  Healthcare Provider
#
#                                   type_coding_system type_coding_code  \
# 0  http://terminology.hl7.org/CodeSystem/organiza...             prov
# 1  http://terminology.hl7.org/CodeSystem/organiza...             prov
#
#    type_coding_display
# 0  Healthcare Provider
# 1  Healthcare Provider
#    resourceType  active gender   name_family
# 0  Practitioner    True   male     Hudson301
# 1  Practitioner    True   male  Cummerata161
#        resourceType          practitioner_display  \
# 0  PractitionerRole     Dr. Valentin929 Hudson301
# 1  PractitionerRole  Dr. Anderson154 Cummerata161
#
#           organization_display         code_text    specialty_text  \
# 0  MOUNT HOPE PHYSICAL THERAPY  General Practice  General Practice
# 1        SAINT ANNE'S HOSPITAL  General Practice  General Practice
#
#               location_display                 code_coding_system  \
# 0  MOUNT HOPE PHYSICAL THERAPY  http://nucc.org/provider-taxonomy
# 1        SAINT ANNE'S HOSPITAL  http://nucc.org/provider-taxonomy
#
#   code_coding_code code_coding_display            specialty_coding_system  \
# 0       208D00000X    General Practice  http://nucc.org/provider-taxonomy
# 1       208D00000X    General Practice  http://nucc.org/provider-taxonomy
#
#   specialty_coding_code specialty_coding_display
# 0            208D00000X         General Practice
# 1            208D00000X         General Practice
#   resourceType    status class_code            subject_display  \
# 0    Encounter  finished        AMB  Mrs. Paulita78 Watsica258
# 1    Encounter  finished        AMB  Mrs. Paulita78 Watsica258
#
#                 period_start                 period_end  \
# 0  1968-03-10T08:49:35-05:00  1968-03-10T09:19:35-05:00
# 1  1968-04-14T08:49:35-05:00  1968-04-14T09:04:35-05:00
#
#        serviceProvider_display                     type_text  \
# 0  MOUNT HOPE PHYSICAL THERAPY  Well child visit (procedure)
# 1  MOUNT HOPE PHYSICAL THERAPY  Well child visit (procedure)
#
#     participant_period_start     participant_period_end  \
# 0  1968-03-10T08:49:35-05:00  1968-03-10T09:19:35-05:00
# 1  1968-04-14T08:49:35-05:00  1968-04-14T09:04:35-05:00
#
#   participant_individual_display    location_location_display  \
# 0      Dr. Valentin929 Hudson301  MOUNT HOPE PHYSICAL THERAPY
# 1      Dr. Valentin929 Hudson301  MOUNT HOPE PHYSICAL THERAPY
#
#        type_coding_system type_coding_code           type_coding_display  \
# 0  http://snomed.info/sct        410620009  Well child visit (procedure)
# 1  http://snomed.info/sct        410620009  Well child visit (procedure)
#
#                              participant_type_coding participant_type_text  \
# 0  [{'system': 'http://terminology.hl7.org/CodeSy...     primary performer
# 1  [{'system': 'http://terminology.hl7.org/CodeSy...     primary performer
#
#   reasonCode_coding_system reasonCode_coding_code  \
# 0   http://snomed.info/sct              195662009
# 1   http://snomed.info/sct               10509002
#
#             reasonCode_coding_display
# 0  Acute viral pharyngitis (disorder)
# 1         Acute bronchitis (disorder)
#   resourceType status          effectiveDateTime  \
# 0  Observation  final  1968-03-10T08:49:35-05:00
# 1  Observation  final  1968-03-10T08:49:35-05:00
#
#                           issued  \
# 0  1968-03-10T08:49:35.715-05:00
# 1  1968-03-10T08:49:35.715-05:00
#
#                                            code_text  valueQuantity_value  \
# 0                                        Body Height                 48.9
# 1  Pain severity - 0-10 verbal numeric rating [Sc...                  2.0
#
#   valueQuantity_unit valueQuantity_code valueCodeableConcept_text  \
# 0                 cm                 cm                       NaN
# 1            {score}            {score}                       NaN
#
#   code_coding_code  ... component_valueQuantity_unit  \
# 0           8302-2  ...                       mm[Hg]
# 1          72514-3  ...                       mm[Hg]
#
#   component_valueQuantity_code  valueCodeableConcept_coding_code  \
# 0                       mm[Hg]                         266919005
# 1                       mm[Hg]                         266919005
#
#   valueCodeableConcept_coding_display  \
# 0      Never smoked tobacco (finding)
# 1      Never smoked tobacco (finding)
#
#                               category_coding_system category_coding_code  \
# 0  http://terminology.hl7.org/CodeSystem/observat...          vital-signs
# 1  http://terminology.hl7.org/CodeSystem/observat...          vital-signs
#
#   category_coding_display component_code_coding_system  \
# 0             vital-signs             http://loinc.org
# 1             vital-signs             http://loinc.org
#
#   component_code_coding_code component_code_coding_display
# 0                     8462-4      Diastolic Blood Pressure
# 1                     8480-6       Systolic Blood Pressure
#
# [2 rows x 23 columns]
#   resourceType     status                              code_text  \
# 0    Procedure  completed  Medication Reconciliation (procedure)
# 1    Procedure  completed  Medication Reconciliation (procedure)
#
#        performedPeriod_start        performedPeriod_end  \
# 0  1968-03-10T08:49:35-05:00  1968-03-10T09:04:35-05:00
# 1  1968-06-16T09:49:35-04:00  1968-06-16T10:04:35-04:00
#
#               location_display code_coding_code  \
# 0  MOUNT HOPE PHYSICAL THERAPY        430193006
# 1  MOUNT HOPE PHYSICAL THERAPY        430193006
#
#                      code_coding_display             reasonReference_display
# 0  Medication Reconciliation (procedure)  Acute viral pharyngitis (disorder)
# 1  Medication Reconciliation (procedure)                   Facial laceration
#        resourceType status          effectiveDateTime  \
# 0  DiagnosticReport  final  1968-03-10T08:49:35-05:00
# 1  DiagnosticReport  final  1968-03-10T08:49:35-05:00
#
#                           issued  \
# 0  1968-03-10T08:49:35.715-05:00
# 1  1968-03-10T08:49:35.715-05:00
#
#                                            code_text  \
# 0  Complete blood count (hemogram) panel - Blood ...
# 1                                                NaN
#
#              performer_display  \
# 0  MOUNT HOPE PHYSICAL THERAPY
# 1    Dr. Valentin929 Hudson301
#
#                                       result_display code_coding_code  \
# 0  Leukocytes [#/volume] in Blood by Automated count          58410-2
# 1  Erythrocytes [#/volume] in Blood by Automated ...          34117-2
#
#                                  code_coding_display  \
# 0  Complete blood count (hemogram) panel - Blood ...
# 1                          History and physical note
#
#   presentedForm_contentType  \
# 0                text/plain
# 1                text/plain
#
#                                   presentedForm_data  \
# 0  CjE5NjgtMDMtMTAKCiMgQ2hpZWYgQ29tcGxhaW50Ck5vIG...
# 1  CjE5NjgtMDQtMTQKCiMgQ2hpZWYgQ29tcGxhaW50Ck5vIG...
#
#                           category_coding_system category_coding_code  \
# 0  http://terminology.hl7.org/CodeSystem/v2-0074                  LAB
# 1                               http://loinc.org              34117-2
#
#      category_coding_display
# 0                 Laboratory
# 1  History and physical note
#         resourceType      status                           date  \
# 0  DocumentReference  superseded  1968-03-10T08:49:35.715-05:00
# 1  DocumentReference  superseded  1968-04-14T08:49:35.715-05:00
#
#              custodian_display       context_period_start  \
# 0  MOUNT HOPE PHYSICAL THERAPY  1968-03-10T08:49:35-05:00
# 1  MOUNT HOPE PHYSICAL THERAPY  1968-04-14T08:49:35-05:00
#
#           context_period_end             author_display  \
# 0  1968-03-10T09:19:35-05:00  Dr. Valentin929 Hudson301
# 1  1968-04-14T09:04:35-05:00  Dr. Valentin929 Hudson301
#
#   content_attachment_contentType  \
# 0                     text/plain
# 1                     text/plain
#
#                              content_attachment_data  \
# 0  CjE5NjgtMDMtMTAKCiMgQ2hpZWYgQ29tcGxhaW50Ck5vIG...
# 1  CjE5NjgtMDQtMTQKCiMgQ2hpZWYgQ29tcGxhaW50Ck5vIG...
#
#                        content_format_code content_format_display  \
# 0  urn:ihe:iti:xds:2017:mimeTypeSufficient    mimeType Sufficient
# 1  urn:ihe:iti:xds:2017:mimeTypeSufficient    mimeType Sufficient
#
#   type_coding_code        type_coding_display  \
# 0          34117-2  History and physical note
# 1          51847-2       Evaluation+Plan note
#
#                               category_coding_system category_coding_code  \
# 0  http://hl7.org/fhir/us/core/CodeSystem/us-core...        clinical-note
# 1  http://hl7.org/fhir/us/core/CodeSystem/us-core...        clinical-note
#
#   category_coding_display
# 0           Clinical Note
# 1           Clinical Note
#    resourceType     status         occurrenceDateTime  primarySource  \
# 0  Immunization  completed  1968-06-16T09:49:35-04:00           True
# 1  Immunization  completed  1968-08-18T09:49:35-04:00           True
#
#   vaccineCode_text             location_display vaccineCode_coding_code  \
# 0              IPV  MOUNT HOPE PHYSICAL THERAPY                      10
# 1              IPV  MOUNT HOPE PHYSICAL THERAPY                      10
#
#   vaccineCode_coding_display
# 0                        IPV
# 1                        IPV
#   resourceType              onsetDateTime          abatementDateTime  \
# 0    Condition  1969-09-03T09:49:35-04:00  1969-09-10T09:49:35-04:00
# 1    Condition  1970-01-29T08:49:35-05:00  1970-02-12T08:49:35-05:00
#
#                 recordedDate                           code_text  \
# 0  1969-09-03T09:49:35-04:00  Acute viral pharyngitis (disorder)
# 1  1970-01-29T08:49:35-05:00                   Facial laceration
#
#   clinicalStatus_coding_code verificationStatus_coding_code code_coding_code  \
# 0                   resolved                      confirmed        195662009
# 1                   resolved                      confirmed        370247008
#
#                   code_coding_display          stage_summary_text  \
# 0  Acute viral pharyngitis (disorder)  Stage 1A (qualifier value)
# 1                   Facial laceration   Stage 1 (qualifier value)
#
#                               category_coding_system category_coding_code  \
# 0  http://terminology.hl7.org/CodeSystem/conditio...  encounter-diagnosis
# 1  http://terminology.hl7.org/CodeSystem/conditio...  encounter-diagnosis
#
#   category_coding_display                        stage_assessment_reference  \
# 0     Encounter Diagnosis  Observation/3549a600-1eb6-4246-9295-2c14c0f2a0d4
# 1     Encounter Diagnosis  Observation/dca10b1a-401c-46e1-a072-2f13e8a4f17b
#
#   stage_type_coding_system stage_type_coding_code  \
# 0   http://snomed.info/sct              260998006
# 1   http://snomed.info/sct              260998006
#
#             stage_type_coding_display stage_summary_coding_system  \
# 0  Clinical staging (qualifier value)      http://snomed.info/sct
# 1  Clinical staging (qualifier value)    http://cancerstaging.org
#
#   stage_summary_coding_code stage_summary_coding_display
# 0                 261634002   Stage 1A (qualifier value)
# 1                       c1A                          NaN
#         resourceType     status intent                 authoredOn  \
# 0  MedicationRequest  completed  order  1970-01-29T08:49:35-05:00
# 1  MedicationRequest  completed  order  1973-05-14T09:49:35-04:00
#
#      medicationCodeableConcept_text             requester_display  \
# 0         Aspirin 81 MG Oral Tablet  Dr. Anderson154 Cummerata161
# 1  Acetaminophen 325 MG Oral Tablet  Dr. Anderson154 Cummerata161
#
#   medicationCodeableConcept_coding_code  \
# 0                                243670
# 1                                313782
#
#   medicationCodeableConcept_coding_display
# 0                Aspirin 81 MG Oral Tablet
# 1         Acetaminophen 325 MG Oral Tablet
#   resourceType    status               period_start  \
# 0     CareTeam  inactive  1970-01-29T08:49:35-05:00
# 1     CareTeam  inactive  1973-05-14T09:49:35-04:00
#
#                   period_end    participant_member_display  \
# 0  1970-02-12T08:49:35-05:00     Mrs. Paulita78 Watsica258
# 1  1974-02-24T09:49:35-04:00  Dr. Anderson154 Cummerata161
#
#                reasonCode_text managingOrganization_display  \
# 0            Facial laceration        SAINT ANNE'S HOSPITAL
# 1  Acute bronchitis (disorder)        SAINT ANNE'S HOSPITAL
#
#                              participant_role_coding  \
# 0  [{'system': 'http://snomed.info/sct', 'code': ...
# 1  [{'system': 'http://snomed.info/sct', 'code': ...
#
#                   participant_role_text reasonCode_coding_system  \
# 0                               Patient   http://snomed.info/sct
# 1  Healthcare professional (occupation)   http://snomed.info/sct
#
#   reasonCode_coding_code    reasonCode_coding_display
# 0              370247008            Facial laceration
# 1               10509002  Acute bronchitis (disorder)
#   resourceType     status intent text_status  \
# 0     CarePlan  completed  order   generated
# 1     CarePlan  completed  order   generated
#
#                                             text_div  \
# 0  <div xmlns="http://www.w3.org/1999/xhtml">Care...
# 1  <div xmlns="http://www.w3.org/1999/xhtml">Care...
#
#                 period_start                 period_end category_text  \
# 0  1970-01-29T08:49:35-05:00  1970-02-12T08:49:35-05:00           NaN
# 1  1973-05-14T09:49:35-04:00  1974-02-24T09:49:35-04:00    Wound care
#
#        activity_detail_code_text activity_detail_status  \
# 0     Dressing change management              completed
# 1  Behavior to prevent infection              completed
#
#   activity_detail_location_display  \
# 0            SAINT ANNE'S HOSPITAL
# 1            SAINT ANNE'S HOSPITAL
#
#                               category_coding_system category_coding_code  \
# 0  http://hl7.org/fhir/us/core/CodeSystem/carepla...          assess-plan
# 1                             http://snomed.info/sct            225358003
#
#   category_coding_display activity_detail_code_coding_system  \
# 0                     NaN             http://snomed.info/sct
# 1              Wound care             http://snomed.info/sct
#
#   activity_detail_code_coding_code activity_detail_code_coding_display
# 0                        385949008          Dressing change management
# 1                        439830001       Behavior to prevent infection

# %%
import requests
import pandas as pd

# Initial URL for the first API call
base_url = "https://clinicaltrials.gov/api/v2/studies"
params = {
    "query.titles": "Breast Cancer",
    "pageSize": 100
}

# Initialize an empty list to store the data
data_list = []

# Loop until there is no nextPageToken
while True:
    # Print the current URL (for debugging purposes)
    print("Fetching data from:", base_url + '?' + '&'.join([f"{k}={v}" for k, v in params.items()]))

    # Send a GET request to the API
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse JSON response
        studies = data.get('studies', [])  # Extract the list of studies

        # Loop through each study and extract specific information
        for study in studies:
            # Safely access nested keys
            nctId = study['protocolSection']['identificationModule'].get('nctId', 'Unknown')
            overallStatus = study['protocolSection']['statusModule'].get('overallStatus', 'Unknown')
            startDate = study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', 'Unknown Date')
            conditions = ', '.join(study['protocolSection']['conditionsModule'].get('conditions', ['No conditions listed']))
            acronym = study['protocolSection']['identificationModule'].get('acronym', 'Unknown')

            # Extract interventions safely
            interventions_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions', [])
            interventions = ', '.join([intervention.get('name', 'No intervention name listed') for intervention in interventions_list]) if interventions_list else "No interventions listed"

            # Extract locations safely
            locations_list = study['protocolSection'].get('contactsLocationsModule', {}).get('locations', [])
            locations = ', '.join([f"{location.get('city', 'No City')} - {location.get('country', 'No Country')}" for location in locations_list]) if locations_list else "No locations listed"

            # Extract dates and phases
            primaryCompletionDate = study['protocolSection']['statusModule'].get('primaryCompletionDateStruct', {}).get('date', 'Unknown Date')
            studyFirstPostDate = study['protocolSection']['statusModule'].get('studyFirstPostDateStruct', {}).get('date', 'Unknown Date')
            lastUpdatePostDate = study['protocolSection']['statusModule'].get('lastUpdatePostDateStruct', {}).get('date', 'Unknown Date')
            studyType = study['protocolSection']['designModule'].get('studyType', 'Unknown')
            phases = ', '.join(study['protocolSection']['designModule'].get('phases', ['Not Available']))

            # Extract eligibility criteria
            #eligibilities = ', '.join(study['protocolSection']['eligibilityModule'].get('eligibilityCriteria', ['No criteria listed']))

            eligibility = study['protocolSection']['eligibilityModule'].get('eligibilityCriteria', 'Unknown')

            #eligibilities_list = study['protocolSection'].get('eligibilityModule', {}).get('eligibilityCriteria', [])
            #eligibilities = ', '.join([eligiblity.get('name', 'No criteria listed') for eligiblity in eligibilities_list]) if eligibilities_list else "No eligibility listed"

            # Append the data to the list as a dictionary
            data_list.append({
                "NCT ID": nctId,
                "Acronym": acronym,
                "Overall Status": overallStatus,
                "Start Date": startDate,
                "Conditions": conditions,
                "Interventions": interventions,
                "Locations": locations,
                "Primary Completion Date": primaryCompletionDate,
                "Study First Post Date": studyFirstPostDate,
                "Last Update Post Date": lastUpdatePostDate,
                "Study Type": studyType,
                "Phases": phases,
                "Eligibility": eligibility
            })

        # Check for nextPageToken and update the params or break the loop
        nextPageToken = data.get('nextPageToken')
        if nextPageToken:
            params['pageToken'] = nextPageToken  # Set the pageToken for the next request
        else:
            break  # Exit the loop if no nextPageToken is present
    else:
        print("Failed to fetch data. Status code:", response.status_code)
        break

# Create a DataFrame from the list of dictionaries
clinical_trials_data = pd.DataFrame(data_list)

# Print the DataFrame
#print(clinical_trials_data)

# Optionally, save the DataFrame to a CSV file
clinical_trials_data.to_csv("clinical_trials_data.csv", index=False)
# Out:
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JeHkvIv
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JWPm_cp
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKHlPQoyA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKDkPApxQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKBlfEsww
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGHk_MtwA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGEl_cqwA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGBlPYrwg
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCHlfQuxg
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCDkPMtxA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCAkfIqyQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JeGk_UtwQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JeDlPgqxQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JeAlPgpww
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JaHlvIpxA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JaElPYgyA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JaBlvUuxg
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JaOkfMpww
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JWFl_ktxw
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JWBlPkhwA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JSHk_YvyA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JSDk_QgyQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JSAm_Ipww
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JuGkPAswA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JuDm_khwg
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JuPkfgvww
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JqGlPEgyA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JqCkfggxQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JqPlvQgyA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKHkPMrww4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKHl_guwAA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKHm_gqwAY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKGkfAuwAU
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKGlPQgyQ8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKGm_cgwgA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKFkPYqwQM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKFlPEvxg4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKFmvYsxg8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKEkPQgxwY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKElPAuxAM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKDkvMrxQU
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKDkfYryA8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKDlfMsxgY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKCkvcvyA4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKClvQqyQU
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKClPghxAQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKBkvAvxg8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKBkPkhxgM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKBlfEtxAY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKAkvMtxQc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKAkfIqxA4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKAlPkswAc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKPkvQqwwI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKPkfQoxwc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKPlPgtwQc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKPm_YqxQI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKOkPcsxg8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKOl_YtxwA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JKOm_IgwAA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGHkfMtxwM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGHl_gpwgM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGHm_Aswg8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGGkPMhww4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGGl_YuyA4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGGmvYhxQc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGFk_gvxw8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGFl_EqxgA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGFmvcqxQI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGEk_YvwgY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGElvcuyAc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGEmvEhwwc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGDk_AqyQQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGDl_QqyAI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGDmvQrwQc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGCkPAtwAI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGCl_YuwgA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGCm_EqxwI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGBkPAoxQI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGBl_cowAY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGBmvgtwAU
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGAkfAhxAA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGAlPctxQM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGAm_YuwQY
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGPkfMtxgQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGPlPIgxgE
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGPm_IrxwM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGOkPUgyQ8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JGOlPYoxg8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCHkvQrwgc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCHlvIpxQI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCHlfUgwg4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCGkvkhxQ4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCGkfgqxQ4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCGlfIqwAM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCFkvQswgI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCFlvEgww4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCFlfAvwgI
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCEkvcpxAM
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCEkfYhyAA
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCElfAuyA8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCDkvIvwQc
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCDkfYhwQ4
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCDlPQuwAE
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCCkvcsxwQ
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCCkfgtxA8
# Fetching data from: https://clinicaltrials.gov/api/v2/studies?query.titles=Breast Cancer&pageSize=100&pageToken=NF0g5JCClfYtxA8

# %%
clinical_trials_data = clinical_trials_data[clinical_trials_data['Overall Status'] == 'RECRUITING']

# %%
pip install openai --upgrade
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.37.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)

# %%
# !pip install langchain_openai --upgrade
# Out:
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.10/dist-packages (0.1.19)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.24 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (0.2.25)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (1.37.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (0.1.94)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.24->langchain_openai) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain_openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain_openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.24->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.24->langchain_openai) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.24->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.24->langchain_openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.0.7)

# %%
import os
from langchain_openai import ChatOpenAI

# os.environ["OPENAI_API_KEY"] = 'sk-proj-XIZYSWf9cabLNiQ4h9HvT3BlbkFJZXRUtBkclFgKigJ7WHuH' # go to platform.openai.com to find your key!
os.environ["OPENAI_API_KEY"] = 'sk-proj-bbcCqgJsIPOhjmiRfNdyT3BlbkFJuDf9IePweh97i2lYZkTl' # API Key from Jieming for MVP
# model
model = "gpt-4-turbo" # most powerful gpt model
llm = ChatOpenAI(temperature=0.1, model=model)

# %%
from openai import OpenAI

client = OpenAI(
  api_key=os.environ["OPENAI_API_KEY"],  # this is also the default, it can be omitted
)

# %% [markdown]
# ### **Part 1:** Querying the LLM with the full health record and the full clinical trials dataframe.

# %%
from datetime import date
today_date = date.today()

# %%
query = f"""You are a doctor seeing a patient diagnosed with a type of breast cancer with the following medical history. {patient}. Extract information about the patient's cancer prognosis and treatment. The patient's age can be inferred from today's data, {today_date} and the patient’s date of birth. Use this information and the clinical trial inclusion/exclusion criteria to identify up to 4 clinical trials that the patient is eligible for. The patient must meet all of the criteria listed for the clinical trial. Identify and report the NCT ID number and the clinical trial eligibility criteria. List four reasons why the patient is eligible for each trial. If the patient does not match the criteria for any of the trials, explain why.{clinical_trials_data}'
"""

#print(query)

response = llm.invoke(query)

# %%
print(response.content)
# Out:
# Based on the provided data, the patient is a female born on March 10, 1968, which makes her 56 years old as of today's date, July 30, 2024. She has been diagnosed with a type of breast cancer, specifically "Malignant neoplasm of breast (disorder)." To find suitable clinical trials for her, we need to consider her age, gender, cancer type, and stage, along with other specific eligibility criteria mentioned in the trials.
#
# From the clinical trials data snippet you provided, I will analyze the eligibility criteria for each trial to determine if the patient qualifies. Here are four clinical trials that the patient might be eligible for, based on the information available:
#
# ### Clinical Trial 1: NCT06155331
# - **Eligibility Criteria:**
#   - Age ≥ 18 years old.
#   - Diagnosed with stage 2 or 3 breast cancer.
#   - Requires chemotherapy.
#   - No prior treatment for the current cancer diagnosis.
#
# **Reasons for Eligibility:**
# 1. The patient is 56 years old, meeting the age criterion.
# 2. She has breast cancer, although the exact stage isn't specified in the data provided; further investigation is needed to confirm the stage.
# 3. The patient's medical history does not mention prior treatment for the current cancer, aligning with the trial's requirement.
# 4. The trial is actively recruiting, which means the patient can potentially participate if other medical conditions align.
#
# ### Clinical Trial 2: NCT04603820
# - **Eligibility Criteria:**
#   - The patient should have a diagnosis of breast cancer.
#   - The patient is pregnant or within one year post-partum.
#   - Willing to provide medical information related to pregnancy and cancer treatment.
#
# **Reasons for Eligibility:**
# 1. The patient has a diagnosis of breast cancer.
# 2. Additional details about her current pregnancy status are required to fully confirm eligibility.
# 3. The trial focuses on the interaction of pregnancy and breast cancer treatment, which might be relevant if the patient is pregnant or was recently.
# 4. This observational study could provide valuable insights into her condition during or after pregnancy.
#
# ### Clinical Trial 3: NCT04074720
# - **Eligibility Criteria:**
#   - Adults >18 years old.
#   - Diagnosed with invasive breast cancer.
#   - Able to provide consent.
#   - No other concurrent malignancies.
#
# **Reasons for Eligibility:**
# 1. The patient is over 18 years old.
# 2. She has a diagnosis of breast cancer, specified as malignant neoplasm which is invasive.
# 3. There is no mention of other concurrent malignancies in her medical history.
# 4. The patient can provide consent if mentally competent.
#
# ### Clinical Trial 4: NCT06087120
# - **Eligibility Criteria:**
#   - Female, 18 years old and above.
#   - Diagnosed with stage II or III breast cancer.
#   - No prior chemotherapy for the current cancer.
#   - Willing to undergo specific treatments listed in the trial.
#
# **Reasons for Eligibility:**
# 1. The patient is female and above 18 years old.
# 2. She has breast cancer, pending confirmation of the specific stage.
# 3. No prior chemotherapy for the current cancer is mentioned in her history.
# 4. Assuming she is willing, she can participate in the treatments required by the trial.
#
# **Note:** For each of these trials, further medical evaluation and detailed information about her current health status, cancer stage, and treatment history are crucial to confirm eligibility. The patient should discuss potential participation with her oncologist, who can provide a more detailed assessment and facilitate the application to these trials if she meets all the criteria.

# %% [markdown]
# ### **Part 2:** Prompt the LLM to write a patient summary, given a full health record.

# %% [markdown]
# #### Summary 1

# %%
query = f"""You are a doctor seeing a patient diagnosed with a type of breast cancer with the following health record in the mCODE format. Write a summary for this patient's cancer prognosis. {patient}'
"""

response = llm.invoke(query)

print(response.content)
# Out:
# The patient, Mrs. Paulita78 Watsica258, has been diagnosed with malignant neoplasm of the breast (breast cancer). The diagnosis was recorded on February 26, 2020. The clinical status of the condition is active, and it has been confirmed. The specific type of breast cancer, based on the SNOMED code provided (254837009), indicates a diagnosis of malignant neoplasm of the breast without further specification of the subtype.
#
# The patient's care has been managed by various healthcare providers, including Dr. Anderson154 Cummerata161 and Dr. Dominique369 Crist667, with encounters primarily at Saint Anne's Hospital. The patient has a history of various conditions and treatments, including acute bronchitis, viral pharyngitis, and procedures like medication reconciliation and radiation therapy.
#
# Given the active status of the breast cancer, ongoing treatment and monitoring are critical. The patient's prognosis will depend on several factors, including the stage of cancer at diagnosis, the specific characteristics of the tumor, response to treatment, and overall health condition. Regular follow-ups and adherence to the treatment plan are essential for managing the condition effectively.
#
# The patient's medical history also includes other conditions such as obesity and a history of normal pregnancies and complications like antepartum eclampsia. These factors may influence the overall management plan for her breast cancer.
#
# It is recommended to continue with a comprehensive care plan that includes regular medical reviews, continued cancer treatment as per oncology guidelines, and supportive care to manage symptoms and improve quality of life. The care team should also consider the patient's past medical history and current health status in managing her treatment plan effectively.

# %% [markdown]
# #### Summary 2

# %%
query = f"""You are a doctor seeing a patient diagnosed with a type of breast cancer with the following health record in the mCODE format. Write a detailed summary for this patient's cancer diagnosis and prognosis. Report the clinical stage type of the cancer diagnosis and other descriptive information about the cancer. Report the gender and the patient's age as of today's date, {today_date}. Report the patient's comorbidities and treatments. {patient}'
"""

response = llm.invoke(query)

print(response.content)
# Out:
# ### Patient Summary
#
# **Patient Details:**
# - **Name:** Mrs. Paulita78 Watsica258
# - **Gender:** Female
# - **Date of Birth:** March 10, 1968
# - **Age:** 56 years old (as of today's date, July 30, 2024)
# - **Marital Status:** Married
# - **Race:** White
# - **Primary Language:** English
#
# **Medical History and Comorbidities:**
# - Mrs. Watsica has a history of various acute conditions such as acute viral pharyngitis, acute bronchitis, and otitis media. She has also experienced facial laceration, epidermal burn, and normal pregnancies. Notably, she has been diagnosed with a malignant neoplasm of the breast (breast cancer) as of February 26, 2020.
#
# **Cancer Diagnosis:**
# - **Type of Cancer:** Malignant neoplasm of the breast
# - **Stage at Diagnosis:** Stage 1A
# - **Date of Diagnosis:** February 26, 2020
# - **Clinical Status:** Active
# - **Verification Status:** Confirmed
#
# **Treatment and Care:**
# - Mrs. Watsica has undergone various treatments and procedures, including radiation therapy care as part of her cancer treatment plan. She has also been prescribed medications like acetaminophen for symptomatic relief of other conditions and has been involved in care plans focusing on respiratory therapy and wound care.
#
# **Healthcare Providers and Locations:**
# - **Primary Care Providers:**
#   - Dr. Anderson154 Cummerata161
#   - Dr. Dominique369 Crist667
# - **Care Locations:**
#   - Saint Anne's Hospital
#   - Mount Hope Physical Therapy
#   - Southcoast Hospital Group, Inc.
#
# **Recent Healthcare Encounters:**
# - Mrs. Watsica has had multiple encounters for problem management at Southcoast Hospital Group, Inc., with the most recent visits focused on managing her breast cancer and associated treatments.
#
# **Prognosis:**
# - Given the early stage of breast cancer at diagnosis (Stage 1A), the prognosis could be cautiously optimistic, depending on her response to treatments, overall health, and absence of significant comorbidities directly impacting her cancer treatment.
#
# **Additional Notes:**
# - Mrs. Watsica has been actively managing her health with regular follow-ups and has been compliant with the treatment regimens prescribed by her healthcare providers. Her care team has been actively involved in her treatment journey, ensuring a multidisciplinary approach to her cancer care and other health concerns.

# %%
patient_summary = response.content

# %%
print(patient_summary)
# Out:
# ### Patient Summary
#
# **Patient Details:**
# - **Name:** Mrs. Paulita78 Watsica258
# - **Gender:** Female
# - **Date of Birth:** March 10, 1968
# - **Age:** 56 years old (as of today's date, July 30, 2024)
# - **Marital Status:** Married
# - **Race:** White
# - **Primary Language:** English
#
# **Medical History and Comorbidities:**
# - Mrs. Watsica has a history of various acute conditions such as acute viral pharyngitis, acute bronchitis, and otitis media. She has also experienced facial laceration, epidermal burn, and normal pregnancies. Notably, she has been diagnosed with a malignant neoplasm of the breast (breast cancer) as of February 26, 2020.
#
# **Cancer Diagnosis:**
# - **Type of Cancer:** Malignant neoplasm of the breast
# - **Stage at Diagnosis:** Stage 1A
# - **Date of Diagnosis:** February 26, 2020
# - **Clinical Status:** Active
# - **Verification Status:** Confirmed
#
# **Treatment and Care:**
# - Mrs. Watsica has undergone various treatments and procedures, including radiation therapy care as part of her cancer treatment plan. She has also been prescribed medications like acetaminophen for symptomatic relief of other conditions and has been involved in care plans focusing on respiratory therapy and wound care.
#
# **Healthcare Providers and Locations:**
# - **Primary Care Providers:**
#   - Dr. Anderson154 Cummerata161
#   - Dr. Dominique369 Crist667
# - **Care Locations:**
#   - Saint Anne's Hospital
#   - Mount Hope Physical Therapy
#   - Southcoast Hospital Group, Inc.
#
# **Recent Healthcare Encounters:**
# - Mrs. Watsica has had multiple encounters for problem management at Southcoast Hospital Group, Inc., with the most recent visits focused on managing her breast cancer and associated treatments.
#
# **Prognosis:**
# - Given the early stage of breast cancer at diagnosis (Stage 1A), the prognosis could be cautiously optimistic, depending on her response to treatments, overall health, and absence of significant comorbidities directly impacting her cancer treatment.
#
# **Additional Notes:**
# - Mrs. Watsica has been actively managing her health with regular follow-ups and has been compliant with the treatment regimens prescribed by her healthcare providers. Her care team has been actively involved in her treatment journey, ensuring a multidisciplinary approach to her cancer care and other health concerns.

# %% [markdown]
# ### **Part 3:** Querying the LLM with the patient summary and the full clinical trials dataframe.

# %%
query = f"""You are a doctor seeing a patient diagnosed with a type of breast cancer with the following medical history. {patient_summary}. Use this information and the clinical trial inclusion/exclusion criteria to identify up to 4 clinical trials that the patient is eligible for. The patient must meet all of the criteria listed for the clinical trial. Identify and report the NCT ID number and the clinical trial eligibility (inclusion and exclusion) criteria. For each eligibility criterion for the trial, explain why the patient is eligible. If the patient does not match the criteria for any of the trials, explain why. {clinical_trials_data}.’
"""

response = llm.invoke(query)

print(response.content)
# Out:
# Based on the patient's medical history and the clinical trial information provided, we can evaluate Mrs. Paulita78 Watsica258's eligibility for the listed clinical trials. Here are the assessments for four selected trials:
#
# ### Trial 1: NCT06155331
# **Eligibility Criteria:**
# - Age ≥ 18 years old.
# - Diagnosed with breast cancer stage 2 or 3.
# - Able to receive chemotherapy.
# - No prior treatment with fenofibrate.
#
# **Reasons for Ineligibility:**
# 1. **Stage of Cancer:** Mrs. Watsica was diagnosed with Stage 1A breast cancer, which does not meet the trial's requirement for stage 2 or 3 breast cancer.
# 2. **Other criteria match,** but the stage mismatch disqualifies her.
#
# ### Trial 2: NCT04603820
# **Eligibility Criteria:**
# - The patient should have breast cancer and be pregnant.
#
# **Reasons for Ineligibility:**
# 1. **Pregnancy Status:** There is no information suggesting that Mrs. Watsica is currently pregnant.
# 2. **Specific Condition Requirement:** The trial specifically requires participants to be pregnant, which is not applicable to Mrs. Watsica.
#
# ### Trial 3: NCT04074720
# **Eligibility Criteria:**
# - Adults >18 years old.
# - Diagnosed with breast cancer.
# - Willing to provide tissue and blood samples.
#
# **Reasons for Eligibility:**
# 1. **Age:** Mrs. Watsica is 56 years old, meeting the age criterion.
# 2. **Diagnosis:** She has been diagnosed with breast cancer.
# 3. **Consent Capability:** There is no indication that she would be unwilling to provide samples; assuming standard consent, she meets this criterion.
# 4. **General Health:** Her medical history does not indicate any conditions that would preclude her from providing samples.
#
# ### Trial 4: NCT06087120
# **Eligibility Criteria:**
# - Female, 18 years old and above.
# - Diagnosed with Stage II breast cancer or higher.
# - Able to participate in the study procedures.
#
# **Reasons for Ineligibility:**
# 1. **Stage of Cancer:** Mrs. Watsica's cancer is Stage 1A, which does not meet the requirement for Stage II or higher.
# 2. **Other criteria match,** but the stage requirement is not met.
#
# ### Conclusion:
# From the trials evaluated, Mrs. Watsica is only potentially eligible for NCT04074720, which involves tissue and blood sample collection from breast cancer patients. The other trials have specific criteria related to the stage of cancer or other conditions (like pregnancy) that do not match her situation. It is crucial to always verify with the patient about any updates in her condition or treatment that might affect eligibility before proceeding with trial enrollment.

# %% [markdown]
# ### **Part 4:** Querying the LLM with the patient summary and the clinical trials data using a RAG-enabled approach

# %%
clinical_trials_data['text'] = 'The trial with NCT ID number ' + clinical_trials_data['NCT ID'] + ' has the following eligbility criteria, for inclusion and exclusion ' + clinical_trials_data['Eligibility']
clinical_trials_data.head()['text']
# Out:
# 14    The trial with NCT ID number NCT06155331 has t...
# 34    The trial with NCT ID number NCT04603820 has t...
# 35    The trial with NCT ID number NCT04074720 has t...
# 38    The trial with NCT ID number NCT06087120 has t...
# 39    The trial with NCT ID number NCT01785420 has t...
# Name: text, dtype: object

# %%
import openai
import tiktoken
from scipy import spatial
import pandas as pd
import ast
import openai

# Function to get text embeddings
def text_embedding(text):
    response = client.embeddings.create(model="text-embedding-ada-002", input=text)
    return response.data[0].embedding

# Apply the text_embedding function to the 'text' column
clinical_trials_data['embedding'] = clinical_trials_data['text'].apply(lambda x: text_embedding(x))

clinical_trials_data = clinical_trials_data.assign(embedding = (clinical_trials_data["text"].apply(lambda x : text_embedding(x))))
print(clinical_trials_data.head())
# Out:
#          NCT ID   Acronym Overall Status  Start Date  \
# 14  NCT06155331   Unknown     RECRUITING     2023-12
# 34  NCT04603820  EMBARCAM     RECRUITING  2019-11-18
# 35  NCT04074720   Unknown     RECRUITING  2018-05-10
# 38  NCT06087120   Unknown     RECRUITING  2023-09-16
# 39  NCT01785420   Unknown     RECRUITING     2013-05
#
#                                            Conditions  \
# 14                        Breast Cancer Stage 2 and 3
# 34                        Breast Cancer and Pregnancy
# 35  Breast Cancer, Invasive Breast Cancer, Carcino...
# 38  Breast Cancer Female, Stage II Breast Cancer, ...
# 39  Carcinoma Breast Stage I, HER2 Positive Breast...
#
#                                         Interventions  \
# 14  Fenofibrate, Placebo, Doxorubicin, Cyclophosph...
# 34                            No interventions listed
# 35  Tissue Sample collection, Blood Sample Collect...
# 38                            No interventions listed
# 39                               Trastuzumab, Placebo
#
#                                             Locations Primary Completion Date  \
# 14                                      Tanta - Egypt                 2024-12
# 34  Oviedo - Spain, Badalona - Spain, Terrassa - S...                 2040-01
# 35                       Philadelphia - United States              2028-08-11
# 38  Ho Chi Minh City - Vietnam, Ho Chi Minh City -...              2025-12-01
# 39                                     Mumbai - India                 2025-04
#
#    Study First Post Date Last Update Post Date      Study Type         Phases  \
# 14            2023-12-04            2023-12-18  INTERVENTIONAL         PHASE4
# 34            2020-10-27            2024-04-15   OBSERVATIONAL  Not Available
# 35            2019-08-30            2023-08-15  INTERVENTIONAL             NA
# 38            2023-10-17            2023-10-18   OBSERVATIONAL  Not Available
# 39            2013-02-07            2023-11-22  INTERVENTIONAL         PHASE3
#
#                                           Eligibility  \
# 14  Inclusion Criteria:\n\n* Age ≥ 18 years old.\n...
# 34  Inclusion Criteria:\n\n1. The patient should h...
# 35  Inclusion Criteria:\n\n* Adults \>18 years old...
# 38  Inclusion Criteria:\n\n* Female,18 years old a...
# 39  Inclusion Criteria:a.\n\n1. Female subjects ag...
#
#                                                  text  \
# 14  The trial with NCT ID number NCT06155331 has t...
# 34  The trial with NCT ID number NCT04603820 has t...
# 35  The trial with NCT ID number NCT04074720 has t...
# 38  The trial with NCT ID number NCT06087120 has t...
# 39  The trial with NCT ID number NCT01785420 has t...
#
#                                             embedding
# 14  [-0.014353722333908081, -0.019298672676086426,...
# 34  [-0.027597151696681976, -0.020099356770515442,...
# 35  [-0.019633859395980835, -0.01601286046206951, ...
# 38  [-0.02823072299361229, -0.006393544841557741, ...
# 39  [-0.033659253269433975, -0.005904540419578552,...

# %%
def strings_ranked_by_relatedness(
    query: str,
    df: pd.DataFrame,
    relatedness_fn = lambda x, y: 1 - spatial.distance.cosine(x, y),
    top_n: int = 1000
):

    EMBEDDING_MODEL = "text-embedding-ada-002"
    query_embedding_response = openai.embeddings.create(
        model = EMBEDDING_MODEL,
        input = query,
    )
    query_embedding = query_embedding_response.data[0].embedding
    strings_and_relatednesses = [
        (row["text"], relatedness_fn(query_embedding, row["embedding"]))
        for i, row in df.iterrows()
    ]
    strings_and_relatednesses.sort(key = lambda x: x[1], reverse = True)
    strings, relatednesses = zip(*strings_and_relatednesses)
    return strings[:top_n], relatednesses[:top_n]

strings, relatednesses = strings_ranked_by_relatedness("Clinical Trials", clinical_trials_data, top_n = 3)
for string, relatedness in zip(strings, relatednesses):
    print(f"{relatedness = :.3f}")
    display(string)

def num_tokens(text: str) -> int:
    encoding = tiktoken.encoding_for_model("gpt-4o")
    return len(encoding.encode(text))

def query_message(
    query: str,
    df: pd.DataFrame,
    model: str,
    token_budget: int
) :
    strings, relatednesses = strings_ranked_by_relatedness(query, df)
    introduction = 'Use the below content to match patients to clinical trials. Explain why the patient does not match any of the eligibility criteria."'
    question = f"\n\nQuestion: {query}"
    message = introduction
    for string in strings:
        next_row = f'\n\nClinical trial section:\n"""\n{string}\n"""'
        if (
            num_tokens(message + next_row + question)
            > token_budget
        ):
            break
        else:
            message += next_row
    return message + question

def ask(
    query: str,
    df: pd.DataFrame = clinical_trials_data,
    model: str = "gpt-4o",
    token_budget: int = 25000,
    print_message: bool = False,
) :
    message = query_message(query, df, model=model, token_budget = token_budget)
    if print_message:
        print(message)
    messages = [
        {"role": "system", "content": "You match patients to clinical trials that they are eligible for."},
        {"role": "user", "content": message},
    ]
    response = openai.chat.completions.create(
        model = model,
        messages = messages,
        temperature = 0
    )
    #response_message = response["choices"][0]["message"]["content"]
    response_message = response.choices[0].message.content
    return response_message
# Out:
# relatedness = 0.817
# 'The trial with NCT ID number NCT05044689 has the following eligbility criteria, for inclusion and exclusion Case Group - Patients must have histologically confirmed diagnosis of colorectal or breast cancer.\n\nControl Group - Patients must not have a diagnosis of cancer.'
# relatedness = 0.816
# 'The trial with NCT ID number NCT05406531 has the following eligbility criteria, for inclusion and exclusion Inclusion Criteria:\n\n* Women over the age of 18\n* Breast cancer patients at the end of adjuvant treatment\n\nExclusion Criteria:\n\n* Patients without a mobil device ("smart" mobile phone)\n* Patients without internet access\n* Patients with diagnosed: psychotic disorder; severe depressive episode; panic disorder; bipolar disorder; personality disorder associated with uncontrollable mood swings; PTSD; suicidal attempts and active suicidal ideation; disability pension due to non-specific mental or somatic problems; hospitalization due to a psychiatric disorder in the past year'
# relatedness = 0.816
# 'The trial with NCT ID number NCT05704842 has the following eligbility criteria, for inclusion and exclusion Inclusion Criteria:\n\n* Women with curative-intent breast cancer who plan to undergo at least 4 cycles of chemotherapy.\n* Age \\> 18 years\n* ECOG performance score \\< 3\n* English-speaking\n* with sufficient vision/hearing or family support\n* Coronary artery disease, if cleared by cardiologist\n* Subject must have smart phone, computer or tablet.\n* Willingness to be randomized\n\nExclusion Criteria:\n\n* Medical or psychiatric conditions (beyond those related to breast cancer and its treatment) that would impair our ability to test study hypotheses (psychotic disorders, dementia, inability to give informed consent or follow instructions).\n* Patients with overt evidence of a psychiatric disorder.\n* Coronary artery disease, not cleared by cardiologist.\n* Contraindication to exercise.\n* Chronic fatigue syndrome.'

# %%
query = f"""You are a doctor seeing a patient diagnosed with a type of breast cancer with the following medical history. {patient_summary}. Use this information and the clinical trial inclusion/exclusion criteria to identify up to 4 clinical trials that the patient is eligible for. The patient must meet all of the criteria listed for the clinical trial. Identify and report the NCT ID number and the clinical trial eligibility (inclusion and exclusion) criteria. For each eligibility criterion for the trial, explain why the patient is eligible. If the patient does not match the criteria for any of the trials, explain why."""

# %%
resp_0 = ask(query)

# %%
print(resp_0)
# Out:
# Based on the provided patient summary and the clinical trial eligibility criteria, Mrs. Paulita78 Watsica258 does not match the criteria for any of the clinical trials listed. Here is a detailed explanation of why she does not match the criteria for each trial:
#
# 1. **NCT04360330**
#    - **Inclusion Criteria:**
#      - Female, ≥ 50 years of age. (Eligible)
#      - Oncotype or MammaPrint diagnosis results are required prior to the start of treatment. (Not mentioned)
#      - Histologically confirmed invasive breast cancer. (Eligible)
#      - Clinical stage T1N0M0. (Eligible)
#      - Receptor status: ER/PR positive and HER2 negative. (Not mentioned)
#      - Unifocal breast cancer. (Not mentioned)
#      - ECOG 0, 1. (Not mentioned)
#      - Ability to undergo MRI. (Not mentioned)
#      - WOCBP must agree to use adequate contraception or agree to undergo sexual abstinence. (Not applicable)
#      - Ability to understand the investigational nature, potential risks and benefits of the research study and willingness to sign the written informed consent and HIPAA document(s). (Eligible)
#    - **Exclusion Criteria:**
#      - Patients without histologically confirmed invasive breast cancer. (Eligible)
#      - Patients without Oncotype or MammaPrint diagnosis results at the start of treatment. (Not mentioned)
#      - Patients with metastatic disease. (Eligible)
#      - ECOG 2, 3, 4. (Not mentioned)
#      - Patients that are unable to undergo MRI. (Not mentioned)
#      - Prior history of radiation to the chest. (Eligible)
#      - History of collagenous disease. (Eligible)
#      - Any serious medical or psychiatric illness/condition likely to interfere or limit compliance with study requirements/treatment. (Eligible)
#      - Diagnosis of another primary malignancy within the last 5 years. (Eligible)
#      - Patients unable to consent, who are pregnant or nursing, or are prisoners. (Eligible)
#
#    **Reason for Ineligibility:** The patient’s receptor status (ER/PR and HER2) and Oncotype or MammaPrint diagnosis results are not provided, which are required for inclusion.
#
# 2. **NCT05033925**
#    - **Inclusion Criteria:**
#      - Female, at least 18 years old. (Eligible)
#      - Welfare scale 0, 1, and 2 (ECOG - WHO). (Not mentioned)
#      - Patients with stage IV breast cancer. (Not eligible, patient has Stage 1A)
#      - Patients who are willing to participate in the test and sign an informed consent. (Eligible)
#      - Patients who undergo breast cancer chemotherapy with luminal B sub-type or triple negative with anthracycline base. (Not mentioned)
#      - Patients who are willing and able to fill out a questionnaire. (Eligible)
#      - The patients who are willing and able to comply with the test protocols during the test. (Eligible)
#    - **Exclusion Criteria:**
#      - Unable to meet the test protocol. (Eligible)
#      - Patients with liver and kidney disorders. (Eligible)
#      - Patients with other diseases/disorders that are meaningful according to the investigators will be excluded from the test. (Eligible)
#      - Patients with cancer that has metastasized to the brain. (Eligible)
#      - Pregnant women and breastfeeding mothers. (Eligible)
#      - Patients with the ejection fraction smaller-than or equal to 55%. (Not mentioned)
#
#    **Reason for Ineligibility:** The patient has Stage 1A breast cancer, not Stage IV.
#
# 3. **NCT04965909**
#    - **Inclusion Criteria:**
#      - Woman aged between 18 - 65 years. (Eligible)
#      - Diagnosis of stage 0 - III breast cancer. (Eligible)
#      - Primary treatment (surgery, radiotherapy and chemotherapy) completed at least 3 months ago may still be receiving hormonal therapy. (Eligible)
#      - Pain related to primary treatment in the last 6 months. (Not mentioned)
#      - Access to Internet and an electronic device that allows the use of the applications used in this study and skills for their use or assistance from a close person who has them. (Eligible)
#      - Ability to communicate fluently verbally and in writing in the language of the research team (Spanish). (Not eligible, primary language is English)
#      - Approval of participation in the study by the coordinator of the health team that assisted her during the course of cancer and its treatment. (Not mentioned)
#    - **Exclusion Criteria:**
#      - Another previous type of cancer or breast cancer recurrence in a period of less than 1 year. (Eligible)
#      - Medical diagnosis of a neurological, autoimmune or cardiovascular disease. (Eligible)
#      - Some type of pathology that is associated with a contraindication to physical exercise. (Eligible)
#      - Diagnosis of serious psychiatric or neurologic disorders that do not allow the participant to follow orders. (Eligible)
#
#    **Reason for Ineligibility:** The patient’s primary language is English, not Spanish.
#
# 4. **NCT05483439**
#    - **Inclusion Criteria:**
#      - Female patients aged ≥ 18 but ≤ 75 years. (Eligible)
#      - Diagnosis of breast cancer meets the following criteria: Stage II-III patients who meet the 8th edition of AJCC Cancer Staging Manual and meet the indications of neoadjuvant therapy. (Not eligible, patient has Stage 1A)
#      - Diagnosis of breast cancer meets the following criteria: Histologically confirmed invasive breast cancer. (Eligible)
#      - KPS score≥70. (Not mentioned)
#      - The functional level of major organs must conform to the following requirements. (Not mentioned)
#      - Patients who participate in the trial voluntarily, sign an informed consent, have good compliance and are willing to comply with the follow-up visit. (Eligible)
#    - **Exclusion Criteria:**
#      - Previously received any anti-tumor therapy (chemotherapy, radiotherapy, molecular targeted therapy, endocrine therapy, etc.). (Not eligible, patient has received radiation therapy)
#      - Patients who are concurrently receiving other anti-tumor therapy. (Eligible)
#      - Bilateral breast cancer, inflammatory breast cancer, or occult breast cancer. (Eligible)
#      - Stage IV breast cancer. (Eligible)
#      - Intolerant to herbs or poor compliance. (Eligible)
#      - With a history of any malignancies other than breast cancer in the past 5 years. (Eligible)
#      - Severe heart, liver, kidney and other important organ dysfunction. (Eligible)
#      - Inability to swallow, chronic diarrhea and intestinal obstruction, and having many factors that affect drug administration and absorption. (Eligible)
#      - Participated in clinical trials of other drugs within 4 weeks before enrollment. (Eligible)
#      - Known history of allergy to the drug components of this regimen. (Eligible)
#      - History of immunodeficiency, including HIV positive, HCV, live active hepatitis B or other acquired or congenital immune deficiency diseases, or a history of organ transplantation. (Eligible)
#      - Have used drugs that affect immune function within 1 year. (Eligible)
#      - Once suffered from any heart disease. (Eligible)
#      - Pregnant, lactating women, fertile women with positive baseline pregnancy test or in the entire women of reproductive age who were unwilling to use effective contraception during the trial. (Eligible)
#      - According to the investigator's judgment, there are comorbidities that seriously endanger the patient's safety or affect the patient's ability to complete the study. (Eligible)
#      - A clear past history of neurological or psychiatric disorders, including epilepsy or dementia. (Eligible)
#
#    **Reason for Ineligibility:** The patient has Stage 1A breast cancer, not Stage II-III.
#
# Given the detailed analysis, Mrs. Watsica does not meet the eligibility criteria for any of the clinical trials listed. The primary reasons include the stage of her breast cancer, missing specific diagnostic results, and language requirements.
